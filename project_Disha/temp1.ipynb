# %%
import pandas as pd
import numpy as np

# %% [markdown]
# crimedata=pd.read_csv('dstrIPC_1')

# %%
crimedata=pd.read_csv('dstrIPC_1')

# %%
crimedata.head(10)
# Out:
#          STATE/UT        DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH        ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH       ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH        CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH        CUDDAPAH  2001      80                 53
# 4  ANDHRA PRADESH   EAST GODAVARI  2001      82                 67
# 5  ANDHRA PRADESH   GUNTAKAL RLY.  2001       3                  1
# 6  ANDHRA PRADESH          GUNTUR  2001     182                 88
# 7  ANDHRA PRADESH  HYDERABAD CITY  2001     111                113
# 8  ANDHRA PRADESH      KARIMNAGAR  2001     162                 85
# 9  ANDHRA PRADESH         KHAMMAM  2001      93                 60
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# ...

# %%
crimedata.shape
# Out:
# (9017, 33)

# %%
np.unique(crimedata['YEAR'])
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012])

# %%
crimedata.dtypes
# Out:
# STATE/UT                                               object
# DISTRICT                                               object
# YEAR                                                    int64
# MURDER                                                  int64
# ATTEMPT TO MURDER                                       int64
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER               int64
# RAPE                                                    int64
# CUSTODIAL RAPE                                          int64
# OTHER RAPE                                              int64
# KIDNAPPING & ABDUCTION                                  int64
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS             int64
# KIDNAPPING AND ABDUCTION OF OTHERS                      int64
# DACOITY                                                 int64
# PREPARATION AND ASSEMBLY FOR DACOITY                    int64
# ROBBERY                                                 int64
# ...

# %%
crimedata.drop(['CUSTODIAL RAPE'],axis=1,inplace=True)

# %%
crimedata['TOTAL IPC CRIMES'].mean(axis=0)
# Out:
# 5310.115115892204

# %%
crimedata.append(['CRIME RATE'])
# Out:
#                0  ARSON  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0            NaN   30.0                                              149.0
# 1            NaN   69.0                                              118.0
# 2            NaN   38.0                                              112.0
# 3            NaN   23.0                                              126.0
# 4            NaN   41.0                                              109.0
# 5            NaN    0.0                                                1.0
# 6            NaN   43.0                                              139.0
# 7            NaN    0.0                                              118.0
# 8            NaN   33.0                                              414.0
# 9            NaN   73.0                                              180.0
# 10           NaN   62.0                                              208.0
# ...

# %%
crimedata.dtypes
# Out:
# STATE/UT                                               object
# DISTRICT                                               object
# YEAR                                                    int64
# MURDER                                                  int64
# ATTEMPT TO MURDER                                       int64
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER               int64
# RAPE                                                    int64
# OTHER RAPE                                              int64
# KIDNAPPING & ABDUCTION                                  int64
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS             int64
# KIDNAPPING AND ABDUCTION OF OTHERS                      int64
# DACOITY                                                 int64
# PREPARATION AND ASSEMBLY FOR DACOITY                    int64
# ROBBERY                                                 int64
# BURGLARY                                                int64
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-1c61be4425f8> in <module>
# ----> 1 crimedata.remove(['CRIME DATA'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'remove'
